# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import seaborn as sns

# %% [markdown]
# 1. Make a new variable that loads the titanic dataset.

# %%
data = pd.read_csv("titanic.csv")
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# 2. Create a seaborn correlation coefficient graph

# %%
#Let's do the heatmap
sns.heatmap(data.corr())

# %% [markdown]
# We can see that the features with the most positively correlated feature pair is SibSp and ParCh.
#
# SibSp = Number of Siblings + Spouses On Board
#
# ParCh = Number of Parents + Children on board
#
# The most negatively correlated feature pair is Passenger Class and Fare, which is to be expected.
#
# An interesting pair of negatively correlated features in the data is passenger class and surival. This suggests that richer passengers tended to survive more.

# %% [markdown]
# Create a Pandas Line Chart on SibSP and Age

# %%
#Use the pandas plot method to do this.
#Use 10 random data points so it's not so crowded.
sample10 = data.sample(10)
sample10
# Out:
#      PassengerId  Survived  Pclass  \
# 818          819         0       3
# 14            15         0       3
# 0              1         0       3
# 849          850         1       1
# 384          385         0       3
# 863          864         0       3
# 690          691         1       1
# 734          735         0       2
# 582          583         0       2
# 356          357         1       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 818              Holm, Mr. John Fredrik Alexander    male  43.0      0      0
# 14           Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0      0
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 849  Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female   NaN      1      0
# 384                        Plotcharsky, Mr. Vasil    male   NaN      0      0
# 863             Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8      2
# 690                       Dick, Mr. Albert Adrian    male  31.0      1      0
# 734                  Troupiansky, Mr. Moses Aaron    male  23.0      0      0
# 582                    Downton, Mr. William James    male  54.0      0      0
# 356                   Bowerman, Miss. Elsie Edith  female  22.0      0      1
#
#         Ticket     Fare Cabin Embarked
# 818     C 7075   6.4500   NaN        S
# 14      350406   7.8542   NaN        S
# 0    A/5 21171   7.2500   NaN        S
# 849      17453  89.1042   C92        C
# 384     349227   7.8958   NaN        S
# 863   CA. 2343  69.5500   NaN        S
# 690      17474  57.0000   B20        S
# 734     233639  13.0000   NaN        S
# 582      28403  26.0000   NaN        S
# 356     113505  55.0000   E33        S

# %%
#This was supposed to be a line chart, though it's a bit easier to see
#as a scatter plot.
data.plot(data.index.name,['SibSp','Age'],kind='line', linestyle="none", marker=".")

# %%
# Use a few data points so it's not so crowded
# Create a pandas bar chart on SibSp and age
sample10["Name"] = sample10["Name"].apply(lambda n: n.split(" ")[0].strip(", "))
sample10.plot("Name", ["SibSp", "Age"], kind="bar")

# %%
# Same bar char, but horizontal
sample10.plot("Name", ["SibSp", "Age"], kind="barh")

# %%
# Same bar chart, but stacked
sample10.plot("Name", ["SibSp", "Age"], kind="bar", stacked=True)

# %%
# Same bar charts, but as subplots
fig, axs = plt.subplots(1, 2)
fig.set_size_inches(15, 5)
axs[0].bar(sample10["Name"], sample10["SibSp"])
axs[1].bar(sample10["Name"], sample10["Age"])

_ = axs[0].set_xticklabels(sample10["Name"], rotation = 90)
_ = axs[1].set_xticklabels(sample10["Name"], rotation = 90)

# %%
#Create a Pandas histogram on Age.
#We can go back to using the full data now for a histogram.
_ = plt.hist(data["Age"])
# Out:
# C:\Users\dpale\anaconda3\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\dpale\anaconda3\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
# Create a pandas density plot on age
# Use the kde method to estimate the pdf of age and plot it
_ = data["Age"].plot.kde(subplots=True)

# %%
# Create a scatter plot in pandas on age and survive
# We'll plot age against survival.
_ = data.plot.scatter("Age", "Survived", figsize=(20,10))
